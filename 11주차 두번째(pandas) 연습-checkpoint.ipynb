# %%
import numpy as np
import pandas as pd

# %%
train=pd.read_csv('C:/Users/moonj/Downloads/train.csv')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train=pd.read_csv('C:/Users/moonj/Downloads/train.csv',header=1 )#헤더옵션 : 열이름이 되는 행을 지정

train
# Out:
#        1  0  3                            Braund, Mr. Owen Harris    male  \
# 0      2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 1      3  1  3                             Heikkinen, Miss. Laina  female
# 2      4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3      5  0  3                           Allen, Mr. William Henry    male
# 4      6  0  3                                   Moran, Mr. James    male
# ..   ... .. ..                                                ...     ...
# 885  887  0  2                              Montvila, Rev. Juozas    male
# 886  888  1  1                       Graham, Miss. Margaret Edith  female
# 887  889  0  3           Johnston, Miss. Catherine Helen "Carrie"  female
# 888  890  1  1                              Behr, Mr. Karl Howell    male
# 889  891  0  3                                Dooley, Mr. Patrick    male
#
#        22  1.1  0.1         A/5 21171     7.25 Unnamed: 10  S
# ...

# %%
train=pd.read_csv('C:/Users/moonj/Downloads/train.csv',header=2 )#헤더옵션 : 열이름이 되는 행을 지정

train
# Out:
#        2  1  1.1 Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  \
# 0      3  1    3                             Heikkinen, Miss. Laina   female
# 1      4  1    1       Futrelle, Mrs. Jacques Heath (Lily May Peel)   female
# 2      5  0    3                           Allen, Mr. William Henry     male
# 3      6  0    3                                   Moran, Mr. James     male
# 4      7  0    1                            McCarthy, Mr. Timothy J     male
# ..   ... ..  ...                                                ...      ...
# 884  887  0    2                              Montvila, Rev. Juozas     male
# 885  888  1    1                       Graham, Miss. Margaret Edith   female
# 886  889  0    3           Johnston, Miss. Catherine Helen "Carrie"   female
# 887  890  1    1                              Behr, Mr. Karl Howell     male
# 888  891  0    3                                Dooley, Mr. Patrick     male
#
# ...

# %%
train=pd.read_csv('C:/Users/moonj/Downloads/train.csv',index_col=False )#index_col 옵션은 데이터 프레임의 행 인덱스가 되는 열을 지정

train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train=pd.read_csv('C:/Users/moonj/Downloads/train.csv',index_col='Pclass' )#index_col 옵션은 데이터 프레임의 행 인덱스가 되는 열을 지정

train
# Out:
#         PassengerId  Survived  \
# Pclass
# 3                 1         0
# 1                 2         1
# 3                 3         1
# 1                 4         1
# 3                 5         0
# ...             ...       ...
# 2               887         0
# 1               888         1
# 3               889         0
# 1               890         1
# 3               891         0
#
#                                                      Name     Sex   Age  \
# Pclass
# 3                                 Braund, Mr. Owen Harris    male  22.0
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                  Heikkinen, Miss. Laina  female  26.0
# 1            Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 3                                Allen, Mr. William Henry    male  35.0
# ...                                                   ...     ...   ...
# ...

# %%
data={'name':['jerry','yuni'],
            'algo':['A+','B']}
df = pd.DataFrame(data)
df.set_index('name',inplace=True)
print(df)
# Out:
#       algo
# name
# jerry   A+
# yuni     B

# %%
df.to_csv('C:/Users/moonj/Downloads/train.csv')#저장하는법
