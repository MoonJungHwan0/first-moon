# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %pip install seaborn -U
# Out:
# Collecting seaborn
#   Downloading seaborn-0.11.1-py3-none-any.whl (285 kB)
# Requirement already satisfied, skipping upgrade: scipy>=1.0 in c:\users\moonj\anaconda3\lib\site-packages (from seaborn) (1.5.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in c:\users\moonj\anaconda3\lib\site-packages (from seaborn) (1.19.2)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.2 in c:\users\moonj\anaconda3\lib\site-packages (from seaborn) (3.3.2)
# Requirement already satisfied, skipping upgrade: pandas>=0.23 in c:\users\moonj\anaconda3\lib\site-packages (from seaborn) (1.1.3)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\moonj\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in c:\users\moonj\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.1)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in c:\users\moonj\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (8.0.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\moonj\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in c:\users\moonj\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied, skipping upgrade: certifi>=2020.06.20 in c:\users\moonj\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2020.6.20)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\moonj\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2020.1)
# Requirement already satisfied, skipping upgrade: six in c:\users\moonj\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.15.0)
# Installing collected packages: seaborn
#   Attempting uninstall: seabornNote: you may need to restart the kernel to use updated packages.
#     Found existing installation: seaborn 0.11.0
#     Uninstalling seaborn-0.11.0:
#       Successfully uninstalled seaborn-0.11.0
# Successfully installed seaborn-0.11.1

# %%
tips = sns.load_dataset("tips")
# seaborn에 탑재된 tips 데이터셋을 사용합니다.

# Plot 0. "total_bill"
xlabel_0 = "Total Bill ($)"
ylabel_0 = "Count"
# X축에 "Total Bill ($)"이라는 레이블을, Y축에 "Count"를 달아줍니다.

# Plot 1. "tip"
xlabel_1 = "Tip ($)"
ylabel_1 = "Density"
# X축에 "Tip ($)"이라는 레이블을, Y축에 "Density"를 달아줍니다.

# Plot 2 & 3, "total_bill" vs "tip"
xlabel_2 = "Total Bill ($)"
ylabel_2 = "Tip ($)"
# X, Y축에 각기 "Total Bill ($)", "Tip ($)"이라는 레이블을 달아줍니다.

# label font
label_fontdict = {"fontsize":14, "fontweight":"bold", "color":"gray"}
labelpad = 12
# 폰트크기는 14, 두껍게("bold") 회색("gray")으로 씁니다.
# X, Y 축과의 거리는 12만큼 띄웁니다.

# ticks
tick_labelsize = "large"
# 눈금의 폰트 크기를 크게("large") 키웁니다.

# colormap
cmap = "Greens"

fig,ax = plt.subplots(figsize=(8,7),ncols=2, nrows=2)
fig.subplots_adjust(wspace=0.5,hspace=0.5)

sns.histplot(ax=ax[0,0], data = tips['total_bill'])
ax[0,0].set_xlabel(xlabel_0)
ax[0,0].set_ylabel(ylabel_0)


sns.kdeplot(ax=ax[0,1],data=tips['total_bill'])
ax[0,1].set_xlabel(xlabel_1)
ax[0,1].set_ylabel(ylabel_1)


sns.histplot(ax=ax[1,0], x=tips['total_bill'], y=tips['tip'], cbar=True, cmap=cmap)
ax[1,0].set_xlabel(xlabel_2)
ax[1,0].set_ylabel(ylabel_2)


sns.kdeplot(ax=ax[1,1],x=tips['total_bill'],y=tips['tip'],cmap=cmap)
ax[1,1].set_xlabel(xlabel_2)
ax[1,1].set_ylabel(ylabel_2)

plt.savefig('abcd')

#각 그래프의 이름은 [Plot 0, 1, 2, 3] =  [histplot, 2D histplot, kdeplot, 2D kdeplot] 입니다

# %%
tips = sns.load_dataset("tips")
# seaborn에 탑재된 tips 데이터셋을 사용합니다.

# label
xlabel = "Day"
ylabel = "Total Bill ($)"
# X축에 "Total Bill ($)"이라는 레이블을, Y축에 "Count"를 달아줍니다.

# label font
label_fontdict = {"fontsize":14, "fontweight":"bold", "color":"gray"}
labelpad = 12
# 폰트크기는 14, 두껍게("bold") 회색("gray")으로 씁니다.
# X, Y 축과의 거리는 12만큼 띄웁니다.

# ticks
tick_labelsize = "large"
# 눈금의 폰트 크기를 크게("large") 키웁니다.

fig,ax =plt.subplots(figsize=(10,12),ncols=2,nrows=3)
fig.subplots_adjust(wspace=0.5,hspace=0.5)

sns.barplot(ax=ax[0][0],data=tips["Day"])
ax[0,0].set_xlabel(xlabel_0)
ax[0,0].set_ylabel(ylabel_0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Day'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-98157e7fbcb1> in <module>
#      20 fig.subplots_adjust(wspace=0.5,hspace=0.5)
#      21
# ---> 22 sns.barplot(ax=ax[0][0],data=tips["Day"])
#      23 ax[0,0].set_xlabel(xlabel_0)
#      24 ax[0,0].set_ylabel(ylabel_0)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Day'
